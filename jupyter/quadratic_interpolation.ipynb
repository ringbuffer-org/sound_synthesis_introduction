# %% [markdown]
# # Quadratic Interpolation
#
# The detection of local maxima in a spectrum is limited to the DFT support points without further processing.
# The following example shows this for a 25 Hz sinusoid at a sampling rate of 100 Hz.

# %%
# %run header.ipynb
 
fs = 100
t  = np.linspace(0,1,fs)

f0 = 25
x  = np.sin(2*np.pi*fs*f0*t)

 

X = abs(np.fft.fft(x))
#X = np.fft.fftshift(X)
f = np.linspace(0,fs,len(X))

fig, ax = plt.subplots()



markers, = ax.plot(f,X, color="gray",ls="none", marker="o");
baseline = ax.axhline(0, color="gray");


verts = np.c_[f, np.zeros_like(f), f, X].reshape(len(t),2,2)
col   = LineCollection(verts)
ax.add_collection(col)

ax.set_xlabel('f [Hz]')
ax.set_ylabel('|X|')
ax.set_xlim(0,fs/2);
#ax.set_ylim(None, 110);
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /tmp/ipykernel_39662/1633148086.py:9
#       7 import matplotlib.pyplot as plt
#       8 from scipy import signal
# ----> 9 import control # z transform etc
#      10 from IPython.display import display, Markdown, clear_output, Math
#      13 import IPython.display as ipd
#
# ModuleNotFoundError: No module named 'control'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('run', 'header.ipynb')
#       3 fs = 100
#       4 t  = np.linspace(0,1,fs)
#
# File ~/Desktop/ringbuffer_env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2482, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2480     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2481 with self.builtin_trap:
# -> 2482     result = fn(*args, **kwargs)
#    2484 # The code below prevents the output from being displayed
#    2485 # when using magics with decorator @output_can_be_silenced
#    2486 # when the last Python token in the expression is a ';'.
#    2487 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Desktop/ringbuffer_env/lib/python3.12/site-packages/IPython/core/magics/execution.py:741, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     739     with preserve_keys(self.shell.user_ns, '__file__'):
#     740         self.shell.user_ns['__file__'] = filename
# --> 741         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     742     return
#     744 # Control the response to exit() calls made by the script being run
#
# File ~/Desktop/ringbuffer_env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3007, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3005 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3006 if raise_exceptions:
# -> 3007     result.raise_error()
#    3008 elif not result.success:
#    3009     break
#
# File ~/Desktop/ringbuffer_env/lib/python3.12/site-packages/IPython/core/interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /tmp/ipykernel_39662/1633148086.py:9
#       7 import matplotlib.pyplot as plt
#       8 from scipy import signal
# ----> 9 import control # z transform etc
#      10 from IPython.display import display, Markdown, clear_output, Math
#      13 import IPython.display as ipd
#
# ModuleNotFoundError: No module named 'control'

# %% [markdown]
# Quadratic or parabolic interpolation can be used to estimate the true peak of the sinusoid. using the detected maximum $a$ and its upper and lower frequency bin.
#
# $p = 0.5  (\alpha-\gamma)/(\alpha-2\beta+\gamma)$
#
# $a^* =  \beta-1/4(\alpha-\gamma)$
#
#
# [More details on JOS Website](https://ccrma.stanford.edu/~jos/parshl/Peak_Detection_Steps_3.html#sec:peakdet)
